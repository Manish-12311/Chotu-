# %%
emp=[
    ["Name", "Age","Gender", "salary"],
    ["Manish", 20,  "male", 24000],
    ["Monu", 19, "male", 18000],
    ["Ashika", 15, "female", 12000],
    ["Nikku", 30, "male", 30000],
    ["Ritu", 17, "female", 20000],
    ["Anand", 28, "male", 40000],
]
import csv
with open("emp.csv","w",newline="") as f:
    wrt = csv.writer(f)
    wrt.writerows(emp)
